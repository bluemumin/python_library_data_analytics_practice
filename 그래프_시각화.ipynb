# %%
import os

import numpy as np
import pandas as pd
from pandas import DataFrame

import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 200

import matplotlib
plt.rc('figure', figsize=(12, 8))

# %% [markdown]
# # matplotlib

# %%
data = np.arange(10)
plt.plot(data)

# %%
fig = plt.figure(figsize=(20,12))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
fig = plt.figure(figsize=(20,12))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2,3, figsize=(12,6))

axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015723953BC8>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True) #모든 subplot들이 같은 눈금을 사용하도록 설정

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0) #그래프간 간격을 없게 조정

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
plt.plot(np.random.randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
plt.plot(np.random.randn(30).cumsum(), 'k--', label='Default')

plt.plot(np.random.randn(30).cumsum(), 'k--', drawstyle='steps-post', label='steps-post')

plt.legend(loc='best'); #알아서 위치 지정

# %% [markdown]
# ## 축 꾸미기

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

ticks = ax.set_xticks([0, 250, 500, 750, 1000])

labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

ax.set_title('My first graph')
ax.set_xlabel('Stage');

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

props = {
    'title' : 'My first graph',
    'xlabel' : 'Stages'
}

ax.set(**props)
# Out:
# [Text(0.5, 0, 'Stages'), Text(0.5, 1.0, 'My first graph')]

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv(r"C:\Users\user\Desktop\파이썬 책\pydata-book-2nd-edition\examples\spx.csv", index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax = ax, style='k-')

crisis_data = [
    (datetime(2007,10,11), 'Peak of bull market'),
    (datetime(2008,3,12), 'Bear'),
    (datetime(2008,9,15), 'Leham')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
               xytext = (date, spx.asof(date) + 250),
                arrowprops = dict(facecolor='black', headwidth=4, width=2, headlength=4),
                horizontalalignment='left', verticalalignment='top'
               ) #지정한 위치에 라벨 추가 및 arrowprops 기능을 통해서 화살표로 보여주는 기능 추가

ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600,1800])
ax.set_title('important dates in the 2008-2009 financial crisis');

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2,0.75), 0.4, 0.15, color='k', alpha=0.3) # 왼쪽 아래가 시작점, 가로 길이, 세로 길이
circ = plt.Circle((0.7,0.2),0.15, color='b', alpha=0.3) #중앙점, 반지름 길이
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5) # 삼각형 세 점

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
plt.savefig('figpath.svg')

# %%
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
from io import BytesIO
buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %%
plt.rc('figure',figsize=(10,10)) #rc 메서드를 사용해서 figure size를 10*10으로 설정

# %%
font_options = {'family' : 'monospace',
               'weight' : 'bold',}
plt.rc('font',**font_options)

# %% [markdown]
# # seaborn

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot()

# %%
fig, axes = plt.subplots(2,1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop') )

data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7);

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.363896  0.462259  0.881761  0.060916
# two    0.305445  0.684455  0.729473  0.506328
# three  0.429832  0.012962  0.589392  0.778593
# four   0.352343  0.410790  0.696102  0.263527
# five   0.251126  0.198322  0.729896  0.417436
# six    0.576138  0.105694  0.359909  0.147850

# %%
df.plot.bar()

# %%
df.plot.barh(stacked=True, alpha=0.5)

# %%
df.plot.barh(stacked=False, alpha=0.5)

# %%
tips = pd.read_csv(r'C:\Users\user\Desktop\파이썬 책\pydata-book-2nd-edition\examples\tips.csv')

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:,2:5]
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_pcts = party_counts.div(party_counts.sum(1), axis=0) # 각 로우 합이 1이 되도록 정규화
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()

# %%
party_pcts.plot.bar(stacked=True)

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h') #hue를 통해서 추가 분류 가능
sns.set(style='whitegrid')

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
tips['tip_pct'].plot.density()

# %%
c1 = np.random.normal(0,1,size=200)
c2 = np.random.normal(10,2,200)
values = pd.Series(np.concatenate([c1,c2]))
values
# Out:
# 0       0.381839
# 1       0.167621
# 2      -0.015192
# 3      -1.135901
# 4      -0.953461
#          ...
# 395     8.736058
# 396     9.719911
# 397    10.749841
# 398     7.890611
# 399     4.753256
# Length: 400, dtype: float64

# %%
sns.distplot(values, bins=100, color='k')

# %%
macro = pd.read_csv(r'C:\Users\user\Desktop\파이썬 책\pydata-book-2nd-edition\examples\macrodata.csv')

data = macro[['cpi','m1','tbilrate','unemp']]
data.tail()
# Out:
#          cpi      m1  tbilrate  unemp
# 198  216.889  1474.7      1.17    6.0
# 199  212.174  1576.5      0.12    6.9
# 200  212.671  1592.8      0.22    8.1
# 201  214.469  1653.6      0.18    9.2
# 202  216.385  1673.9      0.12    9.6

# %%
np.log(data)
# Out:
#           cpi        m1  tbilrate     unemp
# 0    3.366606  4.939497  1.036737  1.757858
# 1    3.372455  4.953712  1.124930  1.629241
# 2    3.379293  4.945207  1.340250  1.667707
# 3    3.379974  4.941642  1.465568  1.722767
# 4    3.385745  4.938781  1.252763  1.648659
# ..        ...       ...       ...       ...
# 198  5.379386  7.296210  0.157004  1.791759
# 199  5.357407  7.362962 -2.120264  1.931521
# 200  5.359746  7.373249 -1.514128  2.091864
# 201  5.368165  7.410710 -1.714798  2.219203
# 202  5.377059  7.422912 -2.120264  2.261763
#
# [203 rows x 4 columns]

# %%
trans_data = np.log(data).diff().dropna() # 이전거에서 현재거를 빼고 만드는 것 # 맨 처음은 NaN이라서 빼고 생성함
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot(x='m1', y='unemp', data=trans_data)
plt.title('change in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'change in log m1 versus log unemp')

# %%
sns.pairplot(trans_data)

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha' : 0.2})

# %% [markdown]
# ### 패싯그리드

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker', kind='bar', data=tips[tips.tip_pct < 1 ])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day', y='tip_pct', row='time', col='smoker', kind='bar', data=tips[tips.tip_pct < 1 ])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='tip_pct', y='day',kind='box', data=tips[tips.tip_pct < 1 ])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
